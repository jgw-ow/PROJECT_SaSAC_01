# %%
import pandas as pd


# CSV 파일 목록
csv_files = ['20211103.csv', '20221109.csv', '20231108.csv', '20241106.csv']

# 각 CSV 파일을 읽어서 DataFrame으로 변환한 후 리스트에 저장
dataframes = [pd.read_csv(file) for file in csv_files]

# 모든 DataFrame을 하나로 합치기
df = pd.concat(dataframes, ignore_index=True)

# 결과 출력
df
# Out:
#       RESPOND_ID  EXAMIN_BEGIN_DE SEXDSTN_FLAG_CD AGRDE_FLAG_NM  \
# 0            434         20211103               M           50대
# 1           1207         20211103               M           50대
# 2           2813         20211103               M           60대
# 3           5144         20211103               F           50대
# 4           5986         20211103               M           60대
# ...          ...              ...             ...           ...
# 2667    53376501         20241106               M           40대
# 2668    53376802         20241106               F           50대
# 2669    53377181         20241106               F           60대
# 2670    53377182         20241106               M           40대
# 2671    53377216         20241106               M           40대
#
#      ANSWRR_OC_AREA_NM HSHLD_INCOME_DGREE_NM  \
# 0                서울특별시              700만원 이상
# 1                  경기도         300이상500만원 미만
# 2                 충청남도         500이상700만원 미만
# ...

# %%
replace_map = {
    '매우 커졌다': '커졌다',
    '조금 커졌다': '커졌다',
    '매우 작아졌다': '작아졌다',
    '조금 작아졌다': '작아졌다'
}

# 재분류할 컬럼들
columns_to_replace = [
    'CLTUR_ART_VIEWNG_INTRST_DGREE_VALUE',
    'CLTUR_ART_ACT_INTRST_DGREE_VALUE',
    'SPORTS_VIEWNG_INTRST_DGREE_VALUE',
    'SPORTS_ACT_INTRST_DGREE_VALUE',
    'TURSM_TOUR_INTRST_DGREE_VALUE',
    'RCRT_REST_INTRST_DGREE_VALUE',
    'SELF_IMPT_SELF_MANAGE_INTRST_DGREE_VALUE',
    'SCT_EXCHG_INTRST_DGREE_VALUE'
]

# 각 컬럼에 대해 재분류 적용
for column in columns_to_replace:
    df[column] = df[column].replace(replace_map)

df
# Out:
#       RESPOND_ID  EXAMIN_BEGIN_DE SEXDSTN_FLAG_CD AGRDE_FLAG_NM  \
# 0            434         20211103               M           50대
# 1           1207         20211103               M           50대
# 2           2813         20211103               M           60대
# 3           5144         20211103               F           50대
# 4           5986         20211103               M           60대
# ...          ...              ...             ...           ...
# 2667    53376501         20241106               M           40대
# 2668    53376802         20241106               F           50대
# 2669    53377181         20241106               F           60대
# 2670    53377182         20241106               M           40대
# 2671    53377216         20241106               M           40대
#
#      ANSWRR_OC_AREA_NM HSHLD_INCOME_DGREE_NM  \
# 0                서울특별시              700만원 이상
# 1                  경기도         300이상500만원 미만
# 2                 충청남도         500이상700만원 미만
# ...

# %%
filtered_df = df[(df['ANSWRR_OC_AREA_NM'] == '서울특별시') & (df['AGRDE_FLAG_NM'] == '20대')]
filtered_df
# Out:
#       RESPOND_ID  EXAMIN_BEGIN_DE SEXDSTN_FLAG_CD AGRDE_FLAG_NM  \
# 106       214604         20211103               M           20대
# 109       218212         20211103               M           20대
# 169       323855         20211103               M           20대
# 200       348213         20211103               M           20대
# 230       368958         20211103               M           20대
# ...          ...              ...             ...           ...
# 2562    53363065         20241106               M           20대
# 2585    53365644         20241106               F           20대
# 2590    53366188         20241106               F           20대
# 2628    53371097         20241106               F           20대
# 2655    53375590         20241106               F           20대
#
#      ANSWRR_OC_AREA_NM HSHLD_INCOME_DGREE_NM  \
# 106              서울특별시              300만원 미만
# 109              서울특별시              300만원 미만
# 169              서울특별시         500이상700만원 미만
# ...

# %%
import pandas as pd


# CSV 파일 목록
csv_files = ['20211103.csv', '20221109.csv', '20231108.csv', '20241106.csv']

# 각 CSV 파일을 읽어서 DataFrame으로 변환한 후 리스트에 저장
dataframes = [pd.read_csv(file) for file in csv_files]

# 모든 DataFrame을 하나로 합치기
df = pd.concat(dataframes, ignore_index=True)


replace_map = {
    '매우 커졌다': '커졌다',
    '조금 커졌다': '커졌다',
    '매우 작아졌다': '작아졌다',
    '조금 작아졌다': '작아졌다'
}

# 재분류할 컬럼들
columns_to_replace = [
    'CLTUR_ART_VIEWNG_INTRST_DGREE_VALUE',
    'CLTUR_ART_ACT_INTRST_DGREE_VALUE',
    'SPORTS_VIEWNG_INTRST_DGREE_VALUE',
    'SPORTS_ACT_INTRST_DGREE_VALUE',
    'TURSM_TOUR_INTRST_DGREE_VALUE',
    'RCRT_REST_INTRST_DGREE_VALUE',
    'SELF_IMPT_SELF_MANAGE_INTRST_DGREE_VALUE',
    'SCT_EXCHG_INTRST_DGREE_VALUE'
]

# 각 컬럼에 대해 재분류 적용
for column in columns_to_replace:
    df[column] = df[column].replace(replace_map)
    
filtered_df = df[(df['ANSWRR_OC_AREA_NM'] == '서울특별시') & (df['AGRDE_FLAG_NM'] == '20대')]
filtered_df
# Out:
#       RESPOND_ID  EXAMIN_BEGIN_DE SEXDSTN_FLAG_CD AGRDE_FLAG_NM  \
# 106       214604         20211103               M           20대
# 109       218212         20211103               M           20대
# 169       323855         20211103               M           20대
# 200       348213         20211103               M           20대
# 230       368958         20211103               M           20대
# ...          ...              ...             ...           ...
# 2562    53363065         20241106               M           20대
# 2585    53365644         20241106               F           20대
# 2590    53366188         20241106               F           20대
# 2628    53371097         20241106               F           20대
# 2655    53375590         20241106               F           20대
#
#      ANSWRR_OC_AREA_NM HSHLD_INCOME_DGREE_NM  \
# 106              서울특별시              300만원 미만
# 109              서울특별시              300만원 미만
# 169              서울특별시         500이상700만원 미만
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# 한글 폰트 설정
font_path = "C:/Windows/Fonts/malgun.ttf"  # Windows의 경우
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# CSV 파일 목록
csv_files = ['20211103.csv', '20221109.csv', '20231108.csv', '20241106.csv']

# 각 CSV 파일을 읽어서 DataFrame으로 변환한 후 리스트에 저장
dataframes = []
for file in csv_files:
    df = pd.read_csv(file, encoding='utf-8')  # 또는 encoding='cp949'
    df['YEAR'] = int(file[:4])  # 파일명에서 연도 추출
    dataframes.append(df)

# 모든 DataFrame을 하나로 합치기
df = pd.concat(dataframes, ignore_index=True)

replace_map = {
    '매우 커졌다': '커졌다',
    '조금 커졌다': '커졌다',
    '매우 작아졌다': '작아졌다',
    '조금 작아졌다': '작아졌다'
}

# 재분류할 컬럼들
columns_to_replace = [
    'CLTUR_ART_VIEWNG_INTRST_DGREE_VALUE',
    'CLTUR_ART_ACT_INTRST_DGREE_VALUE',
    'SPORTS_VIEWNG_INTRST_DGREE_VALUE',
    'SPORTS_ACT_INTRST_DGREE_VALUE',
    'TURSM_TOUR_INTRST_DGREE_VALUE',
    'RCRT_REST_INTRST_DGREE_VALUE',
    'SELF_IMPT_SELF_MANAGE_INTRST_DGREE_VALUE',
    'SCT_EXCHG_INTRST_DGREE_VALUE'
]

# 각 컬럼에 대해 재분류 적용
for column in columns_to_replace:
    df[column] = df[column].replace(replace_map)

# 특정 조건에 맞는 데이터 필터링
filtered_df = df[(df['ANSWRR_OC_AREA_NM'] == '서울특별시') & (df['AGRDE_FLAG_NM'] == '20대')]

# 연도별로 'CLTUR_ART_VIEWNG_INTRST_DGREE_VALUE' 컬럼의 카테고리 값 비율 계산
category_counts = filtered_df.groupby(['YEAR', 'CLTUR_ART_VIEWNG_INTRST_DGREE_VALUE']).size().unstack(fill_value=0)
category_ratios = category_counts.div(category_counts.sum(axis=1), axis=0)

# 그래프 그리기
category_ratios.plot(kind='bar', stacked=True)
plt.title('연도별 CLTUR_ART_VIEWNG_INTRST_DGREE_VALUE 카테고리 비율')
plt.xlabel('연도')
plt.ylabel('비율')
plt.legend(title='카테고리 값')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# 한글 폰트 설정
font_path = "C:/Windows/Fonts/malgun.ttf"  # Windows의 경우
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# CSV 파일 목록
csv_files = ['20211103.csv', '20221109.csv', '20231108.csv', '20241106.csv']

# 각 CSV 파일을 읽어서 DataFrame으로 변환한 후 리스트에 저장
dataframes = []
for file in csv_files:
    df = pd.read_csv(file, encoding='utf-8')  # 또는 encoding='cp949'
    df['YEAR'] = int(file[:4])  # 파일명에서 연도 추출
    dataframes.append(df)

# 모든 DataFrame을 하나로 합치기
df = pd.concat(dataframes, ignore_index=True)

replace_map = {
    '매우 커졌다': '커졌다',
    '조금 커졌다': '커졌다',
    '매우 작아졌다': '작아졌다',
    '조금 작아졌다': '작아졌다'
}

# 재분류할 컬럼들
columns_to_replace = [
    'CLTUR_ART_VIEWNG_INTRST_DGREE_VALUE',
    'CLTUR_ART_ACT_INTRST_DGREE_VALUE',
    'SPORTS_VIEWNG_INTRST_DGREE_VALUE',
    'SPORTS_ACT_INTRST_DGREE_VALUE',
    'TURSM_TOUR_INTRST_DGREE_VALUE',
    'RCRT_REST_INTRST_DGREE_VALUE',
    'SELF_IMPT_SELF_MANAGE_INTRST_DGREE_VALUE',
    'SCT_EXCHG_INTRST_DGREE_VALUE'
]

# 각 컬럼에 대해 재분류 적용
for column in columns_to_replace:
    df[column] = df[column].replace(replace_map)

# 특정 조건에 맞는 데이터 필터링
filtered_df = df[(df['ANSWRR_OC_AREA_NM'] == '서울특별시') & (df['AGRDE_FLAG_NM'] == '20대')]

# 연도별로 'CLTUR_ART_VIEWNG_INTRST_DGREE_VALUE' 컬럼의 카테고리 값 비율 계산
category_counts = filtered_df.groupby(['YEAR', 'CLTUR_ART_VIEWNG_INTRST_DGREE_VALUE']).size().unstack(fill_value=0)
category_ratios = category_counts.div(category_counts.sum(axis=1), axis=0)

# 그래프 그리기
category_ratios.plot(kind='line', marker='o')
plt.title('연도별 CLTUR_ART_VIEWNG_INTRST_DGREE_VALUE 카테고리 비율')
plt.xlabel('연도')
plt.ylabel('비율')
plt.legend(title='카테고리 값')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# 한글 폰트 설정
font_path = "C:/Windows/Fonts/malgun.ttf"  # Windows의 경우
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# CSV 파일 목록
csv_files = ['20211103.csv', '20221109.csv', '20231108.csv', '20241106.csv']

# 각 CSV 파일을 읽어서 DataFrame으로 변환한 후 리스트에 저장
dataframes = []
for file in csv_files:
    df = pd.read_csv(file, encoding='utf-8')  # 또는 encoding='cp949'
    df['YEAR'] = int(file[:4])  # 파일명에서 연도 추출
    dataframes.append(df)

# 모든 DataFrame을 하나로 합치기
df = pd.concat(dataframes, ignore_index=True)

replace_map = {
    '매우 커졌다': '커졌다',
    '조금 커졌다': '커졌다',
    '매우 작아졌다': '작아졌다',
    '조금 작아졌다': '작아졌다'
}

# 재분류할 컬럼들
columns_to_replace = [
    'CLTUR_ART_VIEWNG_INTRST_DGREE_VALUE',
    'CLTUR_ART_ACT_INTRST_DGREE_VALUE',
    'SPORTS_VIEWNG_INTRST_DGREE_VALUE',
    'SPORTS_ACT_INTRST_DGREE_VALUE',
    'TURSM_TOUR_INTRST_DGREE_VALUE',
    'RCRT_REST_INTRST_DGREE_VALUE',
    'SELF_IMPT_SELF_MANAGE_INTRST_DGREE_VALUE',
    'SCT_EXCHG_INTRST_DGREE_VALUE'
]

# 각 컬럼에 대해 재분류 적용
for column in columns_to_replace:
    df[column] = df[column].replace(replace_map)

# 특정 조건에 맞는 데이터 필터링
filtered_df = df[(df['ANSWRR_OC_AREA_NM'] == '서울특별시') & (df['AGRDE_FLAG_NM'] == '20대')]

# 각 컬럼에 대해 그래프 그리기
for column in columns_to_replace:
    # 연도별로 컬럼의 카테고리 값 비율 계산
    category_counts = filtered_df.groupby(['YEAR', column]).size().unstack(fill_value=0)
    category_ratios = category_counts.div(category_counts.sum(axis=1), axis=0)
    
    # 그래프 그리기
    category_ratios.plot(kind='line', marker='o')
    # category_ratios.plot(kind='bar')

    plt.title(f'연도별 {column} 카테고리 비율')
    plt.xlabel('연도')
    plt.ylabel('비율')
    plt.legend(title='카테고리 값')
    plt.grid(True)
    plt.show()

# %%
# '비슷하다' 카테고리 값을 제외
for column in columns_to_replace:
    # '비슷하다'를 제외한 카테고리만 필터링
    category_counts = filtered_df.groupby(['YEAR', column]).size().unstack(fill_value=0)
    category_ratios = category_counts.div(category_counts.sum(axis=1), axis=0)
    
    # '비슷하다' 값이 있는 열을 제거
    category_ratios = category_ratios.drop(columns=['비슷하다'], errors='ignore')  # errors='ignore'로 없으면 무시

    # 그래프 그리기
    category_ratios.plot(kind='line', marker='o')
    plt.title(f'연도별 {column} 카테고리 비율')
    plt.xlabel('연도')
    plt.ylabel('비율')
    plt.legend(title='카테고리 값')
    plt.grid(True)
    plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# 한글 폰트 설정
font_path = "C:/Windows/Fonts/malgun.ttf"  # Windows의 경우
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# CSV 파일 목록
csv_files = ['20211103.csv', '20221109.csv', '20231108.csv', '20241106.csv']

# 각 CSV 파일을 읽어서 DataFrame으로 변환한 후 리스트에 저장
dataframes = []
for file in csv_files:
    df = pd.read_csv(file, encoding='utf-8')  # 또는 encoding='cp949'
    df['YEAR'] = int(file[:4])  # 파일명에서 연도 추출
    dataframes.append(df)

# 모든 DataFrame을 하나로 합치기
df = pd.concat(dataframes, ignore_index=True)

replace_map = {
    '매우 커졌다': '커졌다',
    '조금 커졌다': '커졌다',
    '매우 작아졌다': '작아졌다',
    '조금 작아졌다': '작아졌다'
}

# 재분류할 컬럼들
columns_to_replace = [
    'CLTUR_ART_ACT_INTRST_DGREE_VALUE',
    'SPORTS_ACT_INTRST_DGREE_VALUE',
    'SCT_EXCHG_INTRST_DGREE_VALUE'
]

# 각 컬럼에 대해 재분류 적용
for column in columns_to_replace:
    df[column] = df[column].replace(replace_map)

# 특정 조건에 맞는 데이터 필터링
filtered_df = df[(df['ANSWRR_OC_AREA_NM'] == '서울특별시') & (df['AGRDE_FLAG_NM'] == '20대')]

# 각 컬럼에 대해 그래프 그리기
for column in columns_to_replace:
    # 연도별로 컬럼의 카테고리 값 비율 계산
    category_counts = filtered_df.groupby(['YEAR', column]).size().unstack(fill_value=0)
    category_ratios = category_counts.div(category_counts.sum(axis=1), axis=0)
    category_ratios = category_ratios.drop(columns=['비슷하다'], errors='ignore')
    
    
    # 그래프 그리기
    category_ratios.plot(kind='line', marker='o')
    plt.title(f'연도별 {column} 카테고리 비율')
    plt.xlabel('연도')
    plt.ylabel('비율')
    plt.legend(title='카테고리 값')
    plt.grid(True)
    plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
# 한글 폰트 설정
font_path = "C:/Windows/Fonts/malgun.ttf"  # Windows의 경우
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)
# CSV 파일 목록
csv_files = ['20211103.csv', '20221109.csv', '20231108.csv', '20241106.csv']
# 각 CSV 파일을 읽어서 DataFrame으로 변환한 후 리스트에 저장
dataframes = []
for file in csv_files:
    df = pd.read_csv(file, encoding='utf-8')  # 또는 encoding='cp949'
    df['YEAR'] = int(file[:4])  # 파일명에서 연도 추출
    dataframes.append(df)
    # 각 컬럼에 대해 재분류 적용 및 '비슷하다' 값 제거
# 모든 DataFrame을 하나로 합치기
df = pd.concat(dataframes, ignore_index=True)
replace_map = {
    '매우 커졌다': '커졌다',
    '조금 커졌다': '커졌다',
    '매우 작아졌다': '작아졌다',
    '조금 작아졌다': '작아졌다'
}
# 재분류할 컬럼들
columns_to_replace = [
    'CLTUR_ART_ACT_INTRST_DGREE_VALUE',
    'SPORTS_ACT_INTRST_DGREE_VALUE',
    'SCT_EXCHG_INTRST_DGREE_VALUE'
]
# 각 컬럼에 대해 재분류 적용
for column in columns_to_replace:
    df[column] = df[column].replace(replace_map)
    df = df[df[column] != '비슷하다']
# 특정 조건에 맞는 데이터 필터링
filtered_df = df[(df['ANSWRR_OC_AREA_NM'] == '서울특별시') & (df['AGRDE_FLAG_NM'] == '20대')]
# 각 컬럼에 대해 그래프 그리기
for column in columns_to_replace:
    # 연도별로 컬럼의 카테고리 값 비율 계산
    category_counts = filtered_df.groupby(['YEAR', column]).size().unstack(fill_value=0)
    category_ratios = category_counts.div(category_counts.sum(axis=1), axis=0)
    # 그래프 그리기
    category_ratios.plot(kind='line', marker='o')
    plt.title(f'연도별 {column} 카테고리 비율')
    plt.xlabel('연도')
    plt.ylabel('비율')
    plt.legend(title='카테고리 값')
    plt.grid(True)
    plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# 한글 폰트 설정
font_path = "C:/Windows/Fonts/malgun.ttf"  # Windows의 경우
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# CSV 파일 목록
csv_files = ['20211103.csv', '20221109.csv', '20231108.csv', '20241106.csv']

# 각 CSV 파일을 읽어서 DataFrame으로 변환한 후 리스트에 저장
dataframes = []
for file in csv_files:
    df = pd.read_csv(file, encoding='utf-8')  # 또는 encoding='cp949'
    df['YEAR'] = int(file[:4])  # 파일명에서 연도 추출
    dataframes.append(df)

# 모든 DataFrame을 하나로 합치기
df = pd.concat(dataframes, ignore_index=True)

# 영어 컬럼명과 한글 컬럼명 매핑 딕셔너리
column_mapping = {
    'RESPOND_ID': '응답자ID',
    'EXAMIN_BEGIN_DE': '조사시작일자',
    'SEXDSTN_FLAG_CD': '성별구분코드',
    'AGRDE_FLAG_NM': '연령대구분명',
    'ANSWRR_OC_AREA_NM': '답변자거주지역명',
    'HSHLD_INCOME_DGREE_NM': '가구소득정도명',
    'CLTUR_ART_VIEWNG_INTRST_DGREE_VALUE': '문화예술관람관심정도값',
    'CLTUR_ART_ACT_INTRST_DGREE_VALUE': '문화예술활동관심정도값',
    'SPORTS_VIEWNG_INTRST_DGREE_VALUE': '스포츠관람관심정도값',
    'SPORTS_ACT_INTRST_DGREE_VALUE': '스포츠활동관심정도값',
    'TURSM_TOUR_INTRST_DGREE_VALUE': '관광여행관심정도값',
    'RCRT_REST_INTRST_DGREE_VALUE': '오락휴식관심정도값',
    'SELF_IMPT_SELF_MANAGE_INTRST_DGREE_VALUE': '본인계발본인관리관심정도값',
    'SCT_EXCHG_INTRST_DGREE_VALUE': '사회교류관심정도값'
}

# 컬럼명 변경
df = df.rename(columns=column_mapping)

# 재분류할 컬럼들
columns_to_replace = [
    '문화예술활동관심정도값',
    '스포츠활동관심정도값',
    '사회교류관심정도값'
]

replace_map = {
    '매우 커졌다': '커졌다',
    '조금 커졌다': '커졌다',
    '매우 작아졌다': '작아졌다',
    '조금 작아졌다': '작아졌다'
}

# 각 컬럼에 대해 재분류 적용
for column in columns_to_replace:
    df[column] = df[column].replace(replace_map)

# 특정 조건에 맞는 데이터 필터링
filtered_df = df[(df['답변자거주지역명'] == '서울특별시') & (df['연령대구분명'] == '20대')]

# 각 컬럼에 대해 그래프 그리기
for column in columns_to_replace:
    # 연도별로 컬럼의 카테고리 값 비율 계산
    category_counts = filtered_df.groupby(['YEAR', column]).size().unstack(fill_value=0)
    category_ratios = category_counts.div(category_counts.sum(axis=1), axis=0)
    
    # '비슷하다' 값을 제외한 카테고리만 필터링
    category_ratios = category_ratios.drop(columns=['비슷하다'], errors='ignore')
    
    # 그래프 그리기
    category_ratios.plot(kind='line', marker='o')
    plt.title(f'연도별 {column} 카테고리 비율')
    plt.xlabel('연도')
    plt.ylabel('비율')
    plt.legend(title='카테고리 값')
    plt.grid(True)
    plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# 한글 폰트 설정
font_path = "C:/Windows/Fonts/malgun.ttf"  # Windows의 경우
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# CSV 파일 목록
csv_files = ['20211103.csv', '20221109.csv', '20231108.csv', '20241106.csv']

# 각 CSV 파일을 읽어서 DataFrame으로 변환한 후 리스트에 저장
dataframes = []
for file in csv_files:
    df = pd.read_csv(file, encoding='utf-8')  # 또는 encoding='cp949'
    df['YEAR'] = int(file[:4])  # 파일명에서 연도 추출
    dataframes.append(df)

# 모든 DataFrame을 하나로 합치기
df = pd.concat(dataframes, ignore_index=True)

# 영어 컬럼명과 한글 컬럼명 매핑 딕셔너리
column_mapping = {
    'RESPOND_ID': '응답자ID',
    'EXAMIN_BEGIN_DE': '조사시작일자',
    'SEXDSTN_FLAG_CD': '성별구분코드',
    'AGRDE_FLAG_NM': '연령대구분명',
    'ANSWRR_OC_AREA_NM': '답변자거주지역명',
    'HSHLD_INCOME_DGREE_NM': '가구소득정도명',
    'CLTUR_ART_VIEWNG_INTRST_DGREE_VALUE': '문화예술관람관심정도값',
    'CLTUR_ART_ACT_INTRST_DGREE_VALUE': '문화예술활동관심정도값',
    'SPORTS_VIEWNG_INTRST_DGREE_VALUE': '스포츠관람관심정도값',
    'SPORTS_ACT_INTRST_DGREE_VALUE': '스포츠활동관심정도값',
    'TURSM_TOUR_INTRST_DGREE_VALUE': '관광여행관심정도값',
    'RCRT_REST_INTRST_DGREE_VALUE': '오락휴식관심정도값',
    'SELF_IMPT_SELF_MANAGE_INTRST_DGREE_VALUE': '본인계발본인관리관심정도값',
    'SCT_EXCHG_INTRST_DGREE_VALUE': '사회교류관심정도값'
}

# 컬럼명 변경
df = df.rename(columns=column_mapping)

# 재분류할 컬럼들
columns_to_replace = [
    '문화예술활동관심정도값',
    '스포츠활동관심정도값',
    '사회교류관심정도값'
]

replace_map = {
    '매우 커졌다': '커졌다',
    '조금 커졌다': '커졌다',
    '매우 작아졌다': '작아졌다',
    '조금 작아졌다': '작아졌다'
}

# 각 컬럼에 대해 재분류 적용
for column in columns_to_replace:
    df[column] = df[column].replace(replace_map)

# 특정 조건에 맞는 데이터 필터링
filtered_df = df[(df['답변자거주지역명'] == '서울특별시') & (df['연령대구분명'] == '20대')]

# 각 컬럼에 대해 그래프 그리기
for column in columns_to_replace:
    # 연도별로 컬럼의 카테고리 값 비율 계산
    category_counts = filtered_df.groupby(['YEAR', column]).size().unstack(fill_value=0)
    category_ratios = category_counts.div(category_counts.sum(axis=1), axis=0)
    
    # '비슷하다' 값을 제외한 카테고리만 필터링
    category_ratios = category_ratios.drop(columns=['비슷하다'], errors='ignore')
    
    # 그래프 그리기
    ax = category_ratios.plot(kind='line', marker='o')
    
    # 범례 순서를 변경 (작아졌다, 커졌다 순으로)
    handles, labels = ax.get_legend_handles_labels()
    ax.legend(handles=[handles[1], handles[0]], labels=[labels[1], labels[0]], title='카테고리 값')
    
    plt.title(f'연도별 {column} 카테고리 비율')
    plt.xlabel('연도')
    plt.ylabel('비율')
    plt.grid(True)
    plt.show()
