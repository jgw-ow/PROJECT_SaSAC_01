# %%
import pandas as pd

# 엑셀 파일 경로
file_path = '2020 ~ 2023년 온라인 쇼핑몰 운영형태별 상품군별 거래액.xlsx'

# 엑셀 파일 읽기
df = pd.read_excel(file_path)  # 첫 번째 행을 컬럼 이름으로 사용

# 데이터프레임 확인
df
# Out:
#           상품군별      2020      2021      2022      2023
# 0        음식서비스  17337092  26159657  26585385  26401165
# 1         생활용품  13953031  15390349  16629707  17305848
# 2  패션용품 및 액세서리   2743555   3319785   3799828   3878538
# 3        사무·문구   1337772   1574241   1781517   1917140
# 4          화장품  12940563  12877171  11063963  11872063
# 5   문화 및 레저서비스    699622   1156701   2450139   2979094

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# 한글 폰트 설정
font_path = "C:/Windows/Fonts/malgun.ttf"  # Windows의 경우
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# 엑셀 파일 경로
file_path = '2020 ~ 2023년 온라인 쇼핑몰 운영형태별 상품군별 거래액.xlsx'

# 엑셀 파일 읽기
df = pd.read_excel(file_path)  # 첫 번째 행을 컬럼 이름으로 사용



# 예시: 실제 컬럼 이름이 '상품군', '2020', '2021', '2022', '2023'인 경우
# 필요한 컬럼만 선택
df_selected = df[['상품군별', 2020, 2021, 2022, 2023]]

# 데이터프레임을 '상품군'을 기준으로 설정
df_selected.set_index('상품군별', inplace=True)

# 데이터프레임 전치 (transpose)
df_transposed = df_selected.T

# 데이터프레임 확인
print(df_transposed)

# 시각화
df_transposed.plot(kind='line', figsize=(14, 8), marker='o')
plt.title('연도별 상품군별 거래액 변화')
plt.xlabel('연도')
plt.ylabel('거래액 (단위: 억 원)')
plt.legend(title='상품군')
plt.grid(True)
plt.show()
# Out:
# 상품군별     음식서비스      생활용품  패션용품 및 액세서리    사무·문구       화장품  문화 및 레저서비스
# 2020  17337092  13953031      2743555  1337772  12940563      699622
# 2021  26159657  15390349      3319785  1574241  12877171     1156701
# 2022  26585385  16629707      3799828  1781517  11063963     2450139
# 2023  26401165  17305848      3878538  1917140  11872063     2979094

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import font_manager, rc

# 한글 폰트 설정
font_path = "C:/Windows/Fonts/malgun.ttf"  # Windows의 경우
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# 엑셀 파일 경로
file_path = '2020 ~ 2023년 온라인 쇼핑몰 운영형태별 상품군별 거래액.xlsx'

# 엑셀 파일 읽기
df = pd.read_excel(file_path)  # 첫 번째 행을 컬럼 이름으로 사용

# 데이터프레임 확인
print(df.head())

# 실제 컬럼 이름 확인
print(df.columns)

# 예시: 실제 컬럼 이름이 '상품군별', '2020', '2021', '2022', '2023'인 경우
# 필요한 컬럼만 선택
df_selected = df[['상품군별', 2020, 2021, 2022, 2023]]

# 데이터프레임을 '상품군별'을 기준으로 설정
df_selected.set_index('상품군별', inplace=True)

# 데이터프레임 전치 (transpose)
df_transposed = df_selected.T

# 데이터프레임 확인
print(df_transposed)

# 히트맵 시각화
plt.figure(figsize=(14, 8))
sns.heatmap(df_transposed, annot=True, fmt=".1f", cmap="YlGnBu", linewidths=.5)
plt.title('연도별 상품군별 거래액 변화')
plt.xlabel('상품군')
plt.ylabel('연도')
plt.show()
# Out:
#           상품군별      2020      2021      2022      2023
# 0        음식서비스  17337092  26159657  26585385  26401165
# 1         생활용품  13953031  15390349  16629707  17305848
# 2  패션용품 및 액세서리   2743555   3319785   3799828   3878538
# 3        사무·문구   1337772   1574241   1781517   1917140
# 4          화장품  12940563  12877171  11063963  11872063
# Index(['상품군별', 2020, 2021, 2022, 2023], dtype='object')
# 상품군별     음식서비스      생활용품  패션용품 및 액세서리    사무·문구       화장품  문화 및 레저서비스
# 2020  17337092  13953031      2743555  1337772  12940563      699622
# 2021  26159657  15390349      3319785  1574241  12877171     1156701
# 2022  26585385  16629707      3799828  1781517  11063963     2450139
# 2023  26401165  17305848      3878538  1917140  11872063     2979094

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import font_manager, rc

# 한글 폰트 설정
font_path = "C:/Windows/Fonts/malgun.ttf"  # Windows의 경우
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# 엑셀 파일 경로
file_path = '2020 ~ 2023년 온라인 쇼핑몰 운영형태별 상품군별 거래액.xlsx'

# 엑셀 파일 읽기
df = pd.read_excel(file_path)  # 첫 번째 행을 컬럼 이름으로 사용

# 데이터프레임 확인
# print(df.head())

# 실제 컬럼 이름 확인
# print(df.columns)

# 예시: 실제 컬럼 이름이 '상품군별', '2020', '2021', '2022', '2023'인 경우
# 필요한 컬럼만 선택
df_selected = df[['상품군별', 2020, 2021, 2022, 2023]]

# 데이터프레임을 '상품군별'을 기준으로 설정
df_selected.set_index('상품군별', inplace=True)

# 증가율 계산
df_growth = df_selected.pct_change(axis='columns') * 100

# 데이터프레임 전치 (transpose)
df_transposed = df_growth.T

# 연도 순서 정렬 (2023, 2022, 2021, 2020)
df_transposed = df_transposed.loc[[2023, 2022, 2021, 2020]]

# 데이터프레임 확인
# print(df_transposed)

# 히트맵 시각화
plt.figure(figsize=(14, 8))
sns.heatmap(df_transposed, annot=True, fmt=".1f", cmap="YlGnBu", linewidths=.5)
plt.title('연도별 상품군별 거래액 증가율 변화')
plt.xlabel('상품군')
plt.ylabel('연도')
plt.show()
# Out:
#           상품군별      2020      2021      2022      2023
# 0        음식서비스  17337092  26159657  26585385  26401165
# 1         생활용품  13953031  15390349  16629707  17305848
# 2  패션용품 및 액세서리   2743555   3319785   3799828   3878538
# 3        사무·문구   1337772   1574241   1781517   1917140
# 4          화장품  12940563  12877171  11063963  11872063
# Index(['상품군별', 2020, 2021, 2022, 2023], dtype='object')
# 상품군별      음식서비스       생활용품  패션용품 및 액세서리      사무·문구        화장품  문화 및 레저서비스
# 2023  -0.692937   4.065862     2.071410   7.612782   7.303893   21.588775
# 2022   1.627422   8.052826    14.460063  13.166726 -14.080795  111.821292
# 2021  50.888379  10.301117    21.003042  17.676330  -0.489870   65.332279
# 2020        NaN        NaN          NaN        NaN        NaN         NaN

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import font_manager, rc
import numpy as np

# 한글 폰트 설정
font_path = "C:/Windows/Fonts/malgun.ttf"  # Windows의 경우
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# 엑셀 파일 경로
file_path = '2020 ~ 2023년 온라인 쇼핑몰 운영형태별 상품군별 거래액.xlsx'

# 엑셀 파일 읽기
df = pd.read_excel(file_path)  # 첫 번째 행을 컬럼 이름으로 사용

# 데이터프레임 확인
# print(df.head())

# 실제 컬럼 이름 확인
# print(df.columns)

# 예시: 실제 컬럼 이름이 '상품군별', '2020', '2021', '2022', '2023'인 경우
# 필요한 컬럼만 선택
df_selected = df[['상품군별', 2020, 2021, 2022, 2023]]

# 데이터프레임을 '상품군별'을 기준으로 설정
df_selected.set_index('상품군별', inplace=True)

# 증가율 계산
df_growth = df_selected.pct_change(axis='columns') * 100

# 2020년도의 증가율을 0으로 설정
df_growth[2020] = 0

# 증가율이 없는 경우 0으로 설정
df_growth = df_growth.fillna(0)

# 데이터프레임 전치 (transpose)
df_transposed = df_growth.T

# 연도 순서 정렬 (2023, 2022, 2021, 2020)
df_transposed = df_transposed.loc[[2023, 2022, 2021, 2020]]

# 데이터프레임 확인
# print(df_transposed)

# 히트맵 시각화
plt.figure(figsize=(14, 8))
cmap = sns.color_palette("YlGnBu", as_cmap=True)
sns.heatmap(df_transposed, annot=True, fmt=".1f", cmap=cmap, linewidths=.5, cbar_kws={'label': '증가율 (%)'})
plt.title('2020-2023년도 상품군별 거래액 증가율 변화')
plt.xlabel('상품군')
plt.ylabel('연도')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import font_manager, rc
import numpy as np

# 한글 폰트 설정
font_path = "C:/Windows/Fonts/malgun.ttf"  # Windows의 경우
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# 엑셀 파일 경로
file_path = '2020 ~ 2023년 온라인 쇼핑몰 운영형태별 상품군별 거래액.xlsx'

# 엑셀 파일 읽기
df = pd.read_excel(file_path)  # 첫 번째 행을 컬럼 이름으로 사용

# 데이터프레임 확인
# print(df.head())

# 실제 컬럼 이름 확인
# print(df.columns)

# 예시: 실제 컬럼 이름이 '상품군별', '2020', '2021', '2022', '2023'인 경우
# 필요한 컬럼만 선택
df_selected = df[['상품군별', 2020, 2021, 2022, 2023]]

# 데이터프레임을 '상품군별'을 기준으로 설정
df_selected.set_index('상품군별', inplace=True)

# 증가율 계산
df_growth = df_selected.pct_change(axis='columns') * 100

# 2020년도의 증가율을 0으로 설정
df_growth[2020] = 0

# 증가율이 없는 경우 0으로 설정
df_growth = df_growth.fillna(0)

# 데이터프레임 전치 (transpose)
df_transposed = df_growth.T

# 연도 순서 정렬 (2023, 2022, 2021, 2020)
df_transposed = df_transposed.loc[[2023, 2022, 2021, 2020]]

# 데이터프레임 확인
# print(df_transposed)

# 히트맵 시각화
plt.figure(figsize=(14, 8))
cmap = sns.color_palette("YlOrRd", as_cmap=True)  # 웜톤 색상 팔레트 사용
sns.heatmap(df_transposed, annot=True, fmt=".1f", cmap=cmap, linewidths=.5, cbar_kws={'label': '증가율 (%)'})
plt.title('2020-2023년도 상품군별 거래액 증가율 변화')
plt.xlabel('상품군')
plt.ylabel('연도')
plt.show()
